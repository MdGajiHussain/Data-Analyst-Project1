# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[3,6,7,2]
c=["r","y","b","g"]
plt.bar(x,y,width=0.5,color=c)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[3,6,7,2]
c=["r","y","b","g"]
plt.bar(x,y,color=c,width=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]
plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")
c=["y","b","m","g"]
plt.bar(x,y,width=0.2,color="r",edgecolor="r",label="populaty")
plt.bar(x,z,width=0.2,color="y",label="populaty")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")

plt.bar(p,y,width,color="r",edgecolor="r",label="populaty")
plt.bar(p1,z,width,color="y",label="populaty1")

plt.xticks(p+width/2,x,rotation=15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]

plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")

plt.barh(x,y,color="r",edgecolor="r",label="populaty")
plt.barh(x,z,color="y",label="populaty")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
plt.scatter(x,y,color="r")
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
colors=["r","y","g","r","g","r","b"]
sizes=[101,200,400,50,20,100,90]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="r")
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
z=[2,4,5,6,1,7,8]
colors=[10,29,30,29,56,20,30]
sizes=[101,200,400,50,20,100,90]
plt.scatter(x,y,c=colors,s=sizes,cmap="viridis",alpha=0.5)
plt.scatter(x,z,color="r",s=sizes,alpha=0.5)

t=plt.colorbar()
t.set_label("colorbar",fontsize=15)
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python" ,"c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]
plt.xlabel("language",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.title("gaji",fontsize=15)
c=["y","b","m","g"]
plt.bar(x,y,width=0.2,color="r",linewidth=5,label="popularity")
plt.bar(x,z,width=0.2,color="y",linewidth=5,label="popularity1")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["python" ,"c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.title("gaji",fontsize=15)

plt.bar(p,y,width=0.2,color="r",linewidth=5,label="popularity")
plt.bar(p1,z,width=0.2,color="y",linewidth=5,label="popularity1")


plt.xticks(p+width/2,x,rotation=10)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python" ,"c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

plt.xlabel("language",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.title("gaji",fontsize=15)

plt.barh(x,y,color="r",label="popularity")
plt.barh(x,z,color="y",label="popularity1")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [28 40 53 13 42 20 32 30 20 23 41 46 54 59 25 25 23 48 22 11 16 47 17 55
#  19 44 43 51 56 20 29 44 54 34 50 17 52 18 26 35 38 46 44 20 28 28 30 44
#  12 57]

# %%
no=[24, 21, 20 ,40 ,45, 58, 50 ,32, 10, 53, 20, 50, 40, 37, 59, 13, 10 ,19, 50, 52, 12, 33, 58 ,52,
 55, 31 ,52, 37 ,51 ,22 ,35, 26, 30, 34 ,37 ,22 ,18, 40 ,21, 32, 43 ,10 ,25 ,42 ,35 ,36, 55, 45,
 34, 45]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r",cumulative=-1,bottom=10,align="left",histtype="bar",label="python")
plt.title("Gaji")
plt.xlabel("python")
plt.ylabel("No")

plt.axvline(45,color="b")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","b","g","y"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1.1,labeldistance=1.1,startangle=0,counterclock=False)

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[10,20,30,40]
y=["c","c++","java","python"]
c=["r","m","b","g"]

plt.pie(x,labels=y,radius=1.2)
plt.pie([1],colors="w")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=["c","c++","java","python","r"]
y=[10,20,30,40,50]
z=[8,6,5,10,20]
c=["b","m","g","y","r"]
width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.bar(x,y,color=c,edgecolor="r",width=0.5,label="populaty")
plt.bar(p1,z,width,color="r",label="populaty1")
plt.xticks(p+width/2,x)

plt.title("Gajii",fontsize=15)
plt.xlabel("language",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[3,6,7,2]
c=["r","y","b","g"]
plt.bar(x,y,color=c,width=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]
plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")
c=["y","b","m","g"]
plt.bar(x,y,width=0.2,color="r",edgecolor="r",label="populaty")
plt.bar(x,z,width=0.2,color="y",label="populaty")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")

plt.bar(p,y,width,color="r",edgecolor="r",label="populaty")
plt.bar(p1,z,width,color="y",label="populaty1")

plt.xticks(p+width/2,x,rotation=15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python","c","c++","java"]
y=[85, 70, 69, 82]
z=[30,50,40,80]

plt.xlabel("language",fontsize=10)
plt.ylabel("No")
plt.title("Gaji")

plt.barh(x,y,color="r",edgecolor="r",label="populaty")
plt.barh(x,z,color="y",label="populaty")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
plt.scatter(x,y,color="r")
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
colors=["r","y","g","r","g","r","b"]
sizes=[101,200,400,50,20,100,90]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="r")
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,4,7,3,1,8,6]
z=[2,4,5,6,1,7,8]
colors=[10,29,30,29,56,20,30]
sizes=[101,200,400,50,20,100,90]
plt.scatter(x,y,c=colors,s=sizes,cmap="viridis",alpha=0.5)
plt.scatter(x,z,color="r",s=sizes,alpha=0.5)

t=plt.colorbar()
t.set_label("colorbar",fontsize=15)
plt.title("scatter plot", fontsize=15)
plt.xlabel("day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

x=["c","c++","java","python"]
y=[1,2,3,4]

plt.scatter (x,y,color="r",marker="*")


plt.title("Gaji")
plt.xlabel("language",fontsize=15)
plt.ylabel("NO",fontsize=15)
plt.grid()
plt.show()

# %%
import matplotlib .pyplot as plt


x=[10,20,30,40,50]
y=["haji","mazid","tahir","shadab","rajaul"]

plt.pie(x,labels=y,autopct="%0.1f%%",radius=0.9,labeldistance=1,counterclock=True)
plt.legend(loc=2)
plt.show()

# %%
import matplotlib .pyplot as plt


x=[10,20,30,40,50]
y=["haji","mazid","tahir","shadab","rajaul"]
plt.stem(x,y,linefmt=":",markerfmt="r",bottom=0)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[10,20,30,40,50]

plt.boxplot(x,notch=False,labels=["python"],patch_artist=True,showmeans=True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13332\2458749572.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,notch=False,labels=["python"],patch_artist=True,showmeans=True)

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,3,2,5,4]
area=[2,4,1,5,2]
area1=[2,4,1,5,2]

l=["y","area","area1"]
plt.stackplot(x,y,area,area1,labels=l,baseline="zero")
plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]


plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.grid()
plt.step(x,y,color="r",marker="o",mfc="b",label="python")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([1,2,3,4,5])

plt.plot(x,y,color="r")

plt.fill_between(x,y,color="g",where=(x>=2) &(y<=4),alpha=0.5)
plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Assuming 'fname' is your image file path
image = Image.open(fname).convert("L")  # Convert to grayscale
image_array = np.array(image)          # Convert PIL Image to NumPy array

plt.imshow(image_array, cmap="gray")
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Assuming 'fname' is your image file path
image = Image.open(fname).convert("L")  # Convert to grayscale
image_array = np.array(image)          # Convert PIL Image to NumPy array

plt.imshow(image_array, cmap="RdBu")
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Assuming 'fname' is your image file path
image = Image.open(fname).convert("L")  # Convert to grayscale
image_array = np.array(image)          # Convert PIL Image to NumPy array

plt.imshow(image_array, cmap="Blues_r")
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Assuming 'fname' is your image file path
image = Image.open(fname).convert("L")  # Convert to grayscale
image_array = np.array(image)          # Convert PIL Image to NumPy array

plt.imshow(image_array, cmap="summer")
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# Assuming 'fname' is your image file path
image = Image.open(fname).convert("L")  # Convert to grayscale
image_array = np.array(image)          # Convert PIL Image to NumPy array

plt.imshow(image_array, cmap="turbo")
plt.title("pacock")
plt.grid()
plt.show()

# %% [markdown]
# matplotlib_pie chart

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=["c","c++","java","python", "c_cart"]
plt.pie(x, labels=y,autopct="%0.1f%%")
plt.legend()
plt.show()
